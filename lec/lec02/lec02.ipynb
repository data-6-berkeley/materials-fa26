# %% [markdown]
# # Lecture 2 - Table Fundamentals
#
# ### Data 6, Fall 2026

# %% [markdown]
# # Importing Libraries

# %%
from datascience import *
import numpy as np

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## Introduction to Tables

# %% [markdown]
# Tables allow us to organize data in a systematic and easy-to-work-with way. Each table consists of **columns**, which represent variables, and **rows**, which represent one individual or observation.
#
# Most of our datasets will be stored in `.csv` files (**CSV** stands for "Comma Separated Values").
#
# We will _import_ CSVs into our notebook using the `Table.read_table(...)` function. Here, `Table` is part of the `datascience` library, which is the main library we will be using to work with tables.

# %% [markdown]
# We can load in the same dataset of [public universities in California](https://en.wikipedia.org/wiki/List_of_colleges_and_universities_in_California) by passing in the _filepath_ string corresponding to where our `.csv` file is in our computer's folder structure. (Don't worry, you don't need to know how this works)

# %%
schools = Table.read_table('data/cal_unis.csv')
schools
# Out:
# Name                                              | Institution | City        | County      | Enrollment | Founded
# California State Polytechnic University, Humboldt | CSU         | Arcata      | Humboldt    | 6025       | 1913
# California State University, Bakersfield          | CSU         | Bakersfield | Kern        | 9613       | 1965
# University of California, Berkeley                | UC          | Berkeley    | Alameda     | 45307      | 1869
# California State University Channel Islands       | CSU         | Camarillo   | Ventura     | 6128       | 2002
# California State University, Dominguez Hills      | CSU         | Carson      | Los Angeles | 16426      | 1960
# California State University, Chico                | CSU         | Chico       | Butte       | 14183      | 1887
# University of California, Davis                   | UC          | Davis       | Yolo        | 39679      | 1905
# California State University, Fresno               | CSU         | Fresno      | Fresno      | 23999      | 1911
# California State University, Fullerton            | CSU         | Fullerton   | Orange      | 40386      | 1957
# California State University, East Bay             | CSU         | Hayward     | Alameda     | 13673      | 1957
# ... (22 rows omitted)

# %% [markdown]
# ### Find Table Dimensions ("first things first")
#
# One of the first things we often want to know about our data or table is how big it is.

# %%
schools.num_rows # Find the number of rows in the `schools` table
# Out:
# 32

# %%
schools.num_columns # Find the number columns in the `schools` table
# Out:
# 6

# %% [markdown]
# `tbl.labels` returns the labels for each of the columns:

# %%
# The result is a "tuple" – think of it as a basic type of list or array (but with parenthesis!)
schools.labels
# Out:
# ('Name', 'Institution', 'City', 'County', 'Enrollment', 'Founded')

# %% [markdown]
# ### Column-first paradigm: Columns are arrays
#
# Each column in a table is an **array**, which is useful when we want to perform arithmetic on entire columns. We can extract a particular column with the `tbl.column(...)` method, where `tbl` is the name of some table.

# %%
schools.column('City') # Return an array containing the city of each school in `some_schools`
# Out:
# array(['Arcata', 'Bakersfield', 'Berkeley', 'Camarillo', 'Carson', 'Chico',
#        'Davis', 'Fresno', 'Fullerton', 'Hayward', 'Irvine', 'Long Beach',
#        'Los Angeles', 'Los Angeles', 'Merced', 'Northridge', 'Pomona',
#        'Riverside', 'Rohnert Park', 'Sacramento', 'San Bernardino',
#        'San Diego', 'San Diego', 'San Francisco', 'San Jose',
#        'San Luis Obispo', 'San Marcos', 'Santa Barbara', 'Santa Cruz',
#        'Seaside-Marina', 'Turlock', 'Vallejo'],
#       dtype='<U15')

# %%
schools.column(2) # Return an array of the city of each school using a column index
# Out:
# array(['Arcata', 'Bakersfield', 'Berkeley', 'Camarillo', 'Carson', 'Chico',
#        'Davis', 'Fresno', 'Fullerton', 'Hayward', 'Irvine', 'Long Beach',
#        'Los Angeles', 'Los Angeles', 'Merced', 'Northridge', 'Pomona',
#        'Riverside', 'Rohnert Park', 'Sacramento', 'San Bernardino',
#        'San Diego', 'San Diego', 'San Francisco', 'San Jose',
#        'San Luis Obispo', 'San Marcos', 'Santa Barbara', 'Santa Cruz',
#        'Seaside-Marina', 'Turlock', 'Vallejo'],
#       dtype='<U15')

# %% [markdown]
# #### `select` and `drop`

# %% [markdown]
# A common workflow when working with tables is to **import** the table, **identify** relevant columns, and then make a **new table** with only the columns we want to work with. The `.select()` and `.drop()` table methods allow us to do just that. Notice how both methods achieve the same result, just by slightly different means.

# %%
schools
# Out:
# Name                                              | Institution | City        | County      | Enrollment | Founded
# California State Polytechnic University, Humboldt | CSU         | Arcata      | Humboldt    | 6025       | 1913
# California State University, Bakersfield          | CSU         | Bakersfield | Kern        | 9613       | 1965
# University of California, Berkeley                | UC          | Berkeley    | Alameda     | 45307      | 1869
# California State University Channel Islands       | CSU         | Camarillo   | Ventura     | 6128       | 2002
# California State University, Dominguez Hills      | CSU         | Carson      | Los Angeles | 16426      | 1960
# California State University, Chico                | CSU         | Chico       | Butte       | 14183      | 1887
# University of California, Davis                   | UC          | Davis       | Yolo        | 39679      | 1905
# California State University, Fresno               | CSU         | Fresno      | Fresno      | 23999      | 1911
# California State University, Fullerton            | CSU         | Fullerton   | Orange      | 40386      | 1957
# California State University, East Bay             | CSU         | Hayward     | Alameda     | 13673      | 1957
# ... (22 rows omitted)

# %%
type(schools.column('Name'))
# Out:
# numpy.ndarray

# %%
type(schools.select('Name', 'Enrollment'))
# Out:
# datascience.tables.Table

# %%
schools.select('Name', 'Enrollment')
# Out:
# Name                                              | Enrollment
# California State Polytechnic University, Humboldt | 6025
# California State University, Bakersfield          | 9613
# University of California, Berkeley                | 45307
# California State University Channel Islands       | 6128
# California State University, Dominguez Hills      | 16426
# California State University, Chico                | 14183
# University of California, Davis                   | 39679
# California State University, Fresno               | 23999
# California State University, Fullerton            | 40386
# California State University, East Bay             | 13673
# ... (22 rows omitted)

# %%
schools.drop('Founded', 'County', 'Institution', 'City')
# Out:
# Name                                              | Enrollment
# California State Polytechnic University, Humboldt | 6025
# California State University, Bakersfield          | 9613
# University of California, Berkeley                | 45307
# California State University Channel Islands       | 6128
# California State University, Dominguez Hills      | 16426
# California State University, Chico                | 14183
# University of California, Davis                   | 39679
# California State University, Fresno               | 23999
# California State University, Fullerton            | 40386
# California State University, East Bay             | 13673
# ... (22 rows omitted)

# %% [markdown]
# **Remember** that _all_ table methods return a **new table**, so the original `schools` table is not modified!

# %%
schools
# Out:
# Name                                              | Institution | City        | County      | Enrollment | Founded
# California State Polytechnic University, Humboldt | CSU         | Arcata      | Humboldt    | 6025       | 1913
# California State University, Bakersfield          | CSU         | Bakersfield | Kern        | 9613       | 1965
# University of California, Berkeley                | UC          | Berkeley    | Alameda     | 45307      | 1869
# California State University Channel Islands       | CSU         | Camarillo   | Ventura     | 6128       | 2002
# California State University, Dominguez Hills      | CSU         | Carson      | Los Angeles | 16426      | 1960
# California State University, Chico                | CSU         | Chico       | Butte       | 14183      | 1887
# University of California, Davis                   | UC          | Davis       | Yolo        | 39679      | 1905
# California State University, Fresno               | CSU         | Fresno      | Fresno      | 23999      | 1911
# California State University, Fullerton            | CSU         | Fullerton   | Orange      | 40386      | 1957
# California State University, East Bay             | CSU         | Hayward     | Alameda     | 13673      | 1957
# ... (22 rows omitted)

# %% [markdown]
# #### Adding Columns

# %% [markdown]
# Another thing we might want to do with a table is add additional columns that provide additional tables. We can use the `tbl.with_columns()` method to add columns to an existing table.

# %%
schools.show(2)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Institution</th> <th>City</th> <th>County</th> <th>Enrollment</th> <th>Founded</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>California State Polytechnic University, Humboldt</td> <td>CSU        </td> <td>Arcata     </td> <td>Humboldt</td> <td>6025      </td> <td>1913   </td>
#         </tr>
#         <tr>
#             <td>California State University, Bakersfield         </td> <td>CSU        </td> <td>Bakersfield</td> <td>Kern    </td> <td>9613      </td> <td>1965   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (30 rows omitted)</p>

# %% [markdown]
# Make a table with a new column "Years since Founding" (as of 2026)

# %%
schools.with_columns(
...
)

# %% [markdown]
# **BONUS**: "County (Full)" with "County" concatenated onto county name. (For example, Humboldt -> Humboldt County)

# %%
schools.with_columns(
    'County (Full)', np.char.add(schools.column("County"), " County") # Or schools.column("County") + " County"
)
# Out:
# Name                                              | Institution | City        | County      | Enrollment | Founded | County (Full)
# California State Polytechnic University, Humboldt | CSU         | Arcata      | Humboldt    | 6025       | 1913    | Humboldt County
# California State University, Bakersfield          | CSU         | Bakersfield | Kern        | 9613       | 1965    | Kern County
# University of California, Berkeley                | UC          | Berkeley    | Alameda     | 45307      | 1869    | Alameda County
# California State University Channel Islands       | CSU         | Camarillo   | Ventura     | 6128       | 2002    | Ventura County
# California State University, Dominguez Hills      | CSU         | Carson      | Los Angeles | 16426      | 1960    | Los Angeles County
# California State University, Chico                | CSU         | Chico       | Butte       | 14183      | 1887    | Butte County
# University of California, Davis                   | UC          | Davis       | Yolo        | 39679      | 1905    | Yolo County
# California State University, Fresno               | CSU         | Fresno      | Fresno      | 23999      | 1911    | Fresno County
# California State University, Fullerton            | CSU         | Fullerton   | Orange      | 40386      | 1957    | Orange County
# California State University, East Bay             | CSU         | Hayward     | Alameda     | 13673      | 1957    | Alameda County
# ... (22 rows omitted)

# %% [markdown]
# ### Filtering with `.where`

# %% [markdown]
# The `tbl.where()` method allows us to filter the table to only the rows that match a certain condition. For right now, the syntax we will use is `tbl.where(label, value)`, where `label` is the column you are filtering by and `value` is the value you want to match to.

# %%
schools.where(...) # Filter the `schools` table to only include UC schools. Hint: Use `are.containing(S)` for your second argument

# %%
schools.where(...) # Filter the `schools` table to only the schools in Los Angeles

# %% [markdown]
# We will learn more complicated uses of `.where()` later, but for now just remember this specific syntax.

# %% [markdown]
# ### Method Chaining
#
# **Method chaining** in Python is when the object returned from one method becomes the object to use in the next method.
#
# Below, `Table()` creates a new empty table.

# %%
# TODO: organize code with more whitespace
states = Table().with_columns('State', make_array('California', 'New York', 'Florida', 'Texas', 'Pennsylvania'), 'Code', make_array('CA', 'NY', 'FL', 'TX', 'PA'),'Population (millions)', make_array(39.3, 19.3, 21.7, 29.3, 12.8)
)
states
# Out:
# State        | Code | Population (millions)
# California   | CA   | 39.3
# New York     | NY   | 19.3
# Florida      | FL   | 21.7
# Texas        | TX   | 29.3
# Pennsylvania | PA   | 12.8

# %% [markdown]
# ### (bonus) Additional methods

# %% [markdown]
# Here are some additional table methods that are also useful.

# %% [markdown]
# #### `show`

# %% [markdown]
# `tbl.show(n)` displays the first `n` rows of `tbl`. If `n` is not specified, it will display the entire table.

# %%
schools.show(3) # Show the first 3 rows of the `schools` table
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Institution</th> <th>City</th> <th>County</th> <th>Enrollment</th> <th>Founded</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>California State Polytechnic University, Humboldt</td> <td>CSU        </td> <td>Arcata     </td> <td>Humboldt</td> <td>6025      </td> <td>1913   </td>
#         </tr>
#         <tr>
#             <td>California State University, Bakersfield         </td> <td>CSU        </td> <td>Bakersfield</td> <td>Kern    </td> <td>9613      </td> <td>1965   </td>
#         </tr>
#         <tr>
#             <td>University of California, Berkeley               </td> <td>UC         </td> <td>Berkeley   </td> <td>Alameda </td> <td>45307     </td> <td>1869   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (29 rows omitted)</p>

# %%
schools.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Institution</th> <th>City</th> <th>County</th> <th>Enrollment</th> <th>Founded</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>California State Polytechnic University, Humboldt       </td> <td>CSU        </td> <td>Arcata         </td> <td>Humboldt       </td> <td>6025      </td> <td>1913   </td>
#         </tr>
#         <tr>
#             <td>California State University, Bakersfield                </td> <td>CSU        </td> <td>Bakersfield    </td> <td>Kern           </td> <td>9613      </td> <td>1965   </td>
#         </tr>
#         <tr>
#             <td>University of California, Berkeley                      </td> <td>UC         </td> <td>Berkeley       </td> <td>Alameda        </td> <td>45307     </td> <td>1869   </td>
#         </tr>
#         <tr>
#             <td>California State University Channel Islands             </td> <td>CSU        </td> <td>Camarillo      </td> <td>Ventura        </td> <td>6128      </td> <td>2002   </td>
#         </tr>
#         <tr>
#             <td>California State University, Dominguez Hills            </td> <td>CSU        </td> <td>Carson         </td> <td>Los Angeles    </td> <td>16426     </td> <td>1960   </td>
#         </tr>
#         <tr>
#             <td>California State University, Chico                      </td> <td>CSU        </td> <td>Chico          </td> <td>Butte          </td> <td>14183     </td> <td>1887   </td>
#         </tr>
#         <tr>
#             <td>University of California, Davis                         </td> <td>UC         </td> <td>Davis          </td> <td>Yolo           </td> <td>39679     </td> <td>1905   </td>
#         </tr>
#         <tr>
#             <td>California State University, Fresno                     </td> <td>CSU        </td> <td>Fresno         </td> <td>Fresno         </td> <td>23999     </td> <td>1911   </td>
#         </tr>
#         <tr>
#             <td>California State University, Fullerton                  </td> <td>CSU        </td> <td>Fullerton      </td> <td>Orange         </td> <td>40386     </td> <td>1957   </td>
#         </tr>
#         <tr>
#             <td>California State University, East Bay                   </td> <td>CSU        </td> <td>Hayward        </td> <td>Alameda        </td> <td>13673     </td> <td>1957   </td>
#         </tr>
#         <tr>
#             <td>University of California, Irvine                        </td> <td>UC         </td> <td>Irvine         </td> <td>Orange         </td> <td>35937     </td> <td>1965   </td>
#         </tr>
#         <tr>
#             <td>California State University, Long Beach                 </td> <td>CSU        </td> <td>Long Beach     </td> <td>Los Angeles    </td> <td>38973     </td> <td>1949   </td>
#         </tr>
#         <tr>
#             <td>University of California, Los Angeles                   </td> <td>UC         </td> <td>Los Angeles    </td> <td>Los Angeles    </td> <td>46430     </td> <td>1882   </td>
#         </tr>
#         <tr>
#             <td>California State University, Los Angeles                </td> <td>CSU        </td> <td>Los Angeles    </td> <td>Los Angeles    </td> <td>26460     </td> <td>1947   </td>
#         </tr>
#         <tr>
#             <td>University of California, Merced                        </td> <td>UC         </td> <td>Merced         </td> <td>Merced         </td> <td>9110      </td> <td>2005   </td>
#         </tr>
#         <tr>
#             <td>California State University, Northridge                 </td> <td>CSU        </td> <td>Northridge     </td> <td>Los Angeles    </td> <td>37579     </td> <td>1958   </td>
#         </tr>
#         <tr>
#             <td>California State Polytechnic University, Pomona         </td> <td>CSU        </td> <td>Pomona         </td> <td>Los Angeles    </td> <td>27503     </td> <td>1938   </td>
#         </tr>
#         <tr>
#             <td>University of California, Riverside                     </td> <td>UC         </td> <td>Riverside      </td> <td>Riverside      </td> <td>26809     </td> <td>1954   </td>
#         </tr>
#         <tr>
#             <td>Sonoma State University                                 </td> <td>CSU        </td> <td>Rohnert Park   </td> <td>Sonoma         </td> <td>6637      </td> <td>1960   </td>
#         </tr>
#         <tr>
#             <td>California State University, Sacramento                 </td> <td>CSU        </td> <td>Sacramento     </td> <td>Sacramento     </td> <td>31818     </td> <td>1947   </td>
#         </tr>
#         <tr>
#             <td>California State University, San Bernardino             </td> <td>CSU        </td> <td>San Bernardino </td> <td>San Bernardino </td> <td>19803     </td> <td>1965   </td>
#         </tr>
#         <tr>
#             <td>University of California, San Diego                     </td> <td>UC         </td> <td>San Diego      </td> <td>San Diego      </td> <td>42006     </td> <td>1960   </td>
#         </tr>
#         <tr>
#             <td>San Diego State University                              </td> <td>CSU        </td> <td>San Diego      </td> <td>San Diego      </td> <td>37402     </td> <td>1897   </td>
#         </tr>
#         <tr>
#             <td>San Francisco State University                          </td> <td>CSU        </td> <td>San Francisco  </td> <td>San Francisco  </td> <td>25282     </td> <td>1899   </td>
#         </tr>
#         <tr>
#             <td>San Jose State University                               </td> <td>CSU        </td> <td>San Jose       </td> <td>Santa Clara    </td> <td>35751     </td> <td>1857   </td>
#         </tr>
#         <tr>
#             <td>California Polytechnic State University, San Luis Obispo</td> <td>CSU        </td> <td>San Luis Obispo</td> <td>San Luis Obispo</td> <td>22000     </td> <td>1901   </td>
#         </tr>
#         <tr>
#             <td>California State University San Marcos                  </td> <td>CSU        </td> <td>San Marcos     </td> <td>San Diego      </td> <td>15109     </td> <td>1988   </td>
#         </tr>
#         <tr>
#             <td>University of California, Santa Barbara                 </td> <td>UC         </td> <td>Santa Barbara  </td> <td>Santa Barbara  </td> <td>26420     </td> <td>1891   </td>
#         </tr>
#         <tr>
#             <td>University of California, Santa Cruz                    </td> <td>UC         </td> <td>Santa Cruz     </td> <td>Santa Cruz     </td> <td>19478     </td> <td>1965   </td>
#         </tr>
#         <tr>
#             <td>California State University, Monterey Bay               </td> <td>CSU        </td> <td>Seaside-Marina </td> <td>Monterey       </td> <td>7045      </td> <td>1994   </td>
#         </tr>
#         <tr>
#             <td>California State University, Stanislaus                 </td> <td>CSU        </td> <td>Turlock        </td> <td>Stanislaus     </td> <td>10154     </td> <td>1957   </td>
#         </tr>
#         <tr>
#             <td>California State University Maritime Academy            </td> <td>CSU        </td> <td>Vallejo        </td> <td>Solano         </td> <td>1017      </td> <td>1929   </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# #### `relabeled`

# %% [markdown]
# You can also relabel the labels in your table using the `tbl.relabed()` method.

# %%
schools.relabeled('Name', 'University').show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>University</th> <th>Institution</th> <th>City</th> <th>County</th> <th>Enrollment</th> <th>Founded</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>California State Polytechnic University, Humboldt</td> <td>CSU        </td> <td>Arcata     </td> <td>Humboldt   </td> <td>6025      </td> <td>1913   </td>
#         </tr>
#         <tr>
#             <td>California State University, Bakersfield         </td> <td>CSU        </td> <td>Bakersfield</td> <td>Kern       </td> <td>9613      </td> <td>1965   </td>
#         </tr>
#         <tr>
#             <td>University of California, Berkeley               </td> <td>UC         </td> <td>Berkeley   </td> <td>Alameda    </td> <td>45307     </td> <td>1869   </td>
#         </tr>
#         <tr>
#             <td>California State University Channel Islands      </td> <td>CSU        </td> <td>Camarillo  </td> <td>Ventura    </td> <td>6128      </td> <td>2002   </td>
#         </tr>
#         <tr>
#             <td>California State University, Dominguez Hills     </td> <td>CSU        </td> <td>Carson     </td> <td>Los Angeles</td> <td>16426     </td> <td>1960   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (27 rows omitted)</p>

# %% [markdown]
# #### `.dtype`

# %% [markdown]
# You can check the type of a column using the `.dtype` function:

# %%
schools.column('Founded').dtype
# Out:
# dtype('int64')

# %% [markdown]
# Strings are a little tricky to interpret...

# %%
schools.column('Institution').dtype
# Out:
# dtype('<U3')

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## Table Practice

# %%
schools = Table.read_table('data/cal_unis.csv')
schools
# Out:
# Name                                              | Institution | City        | County      | Enrollment | Founded
# California State Polytechnic University, Humboldt | CSU         | Arcata      | Humboldt    | 6025       | 1913
# California State University, Bakersfield          | CSU         | Bakersfield | Kern        | 9613       | 1965
# University of California, Berkeley                | UC          | Berkeley    | Alameda     | 45307      | 1869
# California State University Channel Islands       | CSU         | Camarillo   | Ventura     | 6128       | 2002
# California State University, Dominguez Hills      | CSU         | Carson      | Los Angeles | 16426      | 1960
# California State University, Chico                | CSU         | Chico       | Butte       | 14183      | 1887
# University of California, Davis                   | UC          | Davis       | Yolo        | 39679      | 1905
# California State University, Fresno               | CSU         | Fresno      | Fresno      | 23999      | 1911
# California State University, Fullerton            | CSU         | Fullerton   | Orange      | 40386      | 1957
# California State University, East Bay             | CSU         | Hayward     | Alameda     | 13673      | 1957
# ... (22 rows omitted)

# %% [markdown]
# ### Exercise 1: Variable names
#
# How do we get all the column labels of `schools`?

# %%
...

# %% [markdown]
# ### Exercise 2: Reorder columns
#
# How do we reorder the columns, as below?
#
# | Name	| Founded |	Institution |City |	County | Enrollment |
# | --- | --- | --- | --- | --- | --- |
# | ... | ... | ... | ... | ... | ... |
#
# Hint: use one of `select`, `drop`, or `with_columns`.

# %%
...

# %% [markdown]
# ### Exercise 3: Rename Columns
#
# How do we **update** `schools` such that the column Name is renamed University? _Hint_: Check out the method `relabeled`.

# %%
# Using `relabeled`

# %% [markdown]
# There are many ways to approach a problem. Suppose you didn't know the method `relabeled` existed:

# %%
# Hint: Try method chaining
schools = Table.read_table('data/cal_unis.csv')
schools = schools.with_column("University", schools.column("Name")).drop("Name")
schools
# Out:
# Institution | City        | County      | Enrollment | Founded | University
# CSU         | Arcata      | Humboldt    | 6025       | 1913    | California State Polytechnic University, Humboldt
# CSU         | Bakersfield | Kern        | 9613       | 1965    | California State University, Bakersfield
# UC          | Berkeley    | Alameda     | 45307      | 1869    | University of California, Berkeley
# CSU         | Camarillo   | Ventura     | 6128       | 2002    | California State University Channel Islands
# CSU         | Carson      | Los Angeles | 16426      | 1960    | California State University, Dominguez Hills
# CSU         | Chico       | Butte       | 14183      | 1887    | California State University, Chico
# UC          | Davis       | Yolo        | 39679      | 1905    | University of California, Davis
# CSU         | Fresno      | Fresno      | 23999      | 1911    | California State University, Fresno
# CSU         | Fullerton   | Orange      | 40386      | 1957    | California State University, Fullerton
# CSU         | Hayward     | Alameda     | 13673      | 1957    | California State University, East Bay
# ... (22 rows omitted)

# %% [markdown]
# ---
#
# ## NoneType

# %% [markdown]
# In Python, `NoneType` is a special data type that represents the absence of a value or the lack of any specific data. It is used to indicate the absence of a meaningful object or variable.
#
# When a function or method does not have a return value or when a variable has not been assigned a value, Python assigns the `None` value to it, and its type becomes `NoneType`.
#
# It is commonly used as a default value, a placeholder, or to signify the failure of an operation.

# %% [markdown]
# The `print` function in Python is used to display information or output on the screen. It allows you to show text, numbers, variables, or any other value to the user or developer during program execution. You can pass multiple arguments to the `print` function, which will be displayed sequentially on a single line by default.

# %%
print("This value is", print(1))
# Out:
# 1
# This value is None
