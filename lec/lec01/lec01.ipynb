# %% [markdown]
# ## Lecture 01

# %% [markdown]
# ## Review from Lab/Challenge

# %%
# Exercise 1
x = 10
x + 2
x

# %%
# Exercise 2
y = x - 4
y

# %%
# Exercise 3
# recall ** is exponentiation/power
y = max(x, y ** 2)
y

# %% [markdown]
# ### What if we ran the previous cell again?

# %% [markdown]
# ## Numeric Data Types

# %% [markdown]
# ### `int` and `float`

# %%
1 + 3

# %%
1234567 * 890

# %%
1234567 ** 20

# %%
0.00003

# %% [markdown]
# ---

# %%
2024

# %%
1012 * 2.0

# %%
10 / 4

# %%
10 //       4

# %% [markdown]
# ---
#
# ### More on `float` values

# %%
10/3

# %%
75892745.21548924758927498571223498230498320948320984023984

# %%
75892745.215489247589274985712 - 75892745.21548925

# %%
.1 + .2

# %% [markdown]
# This is a consequence of how numbers (in particular, floats) are stored in computers. There’s nothing we can really do about it, but you should be aware of it!

# %% [markdown]
# ---
#
# ### Every value has a **data type**

# %%
type(10 // 2)

# %%
a = 10

# %%
type(a * 2.0)

# %%
type(1012 * 2)

# %%
type(4048/2)

# %%
type(1234567 ** 20)

# %%
type(max)

# %%
type(abs)

# %%
type(abs(20))

# %%
abs(-20.45687)

# %% [markdown]
# ---
#
# ## Strings

# %%
'Flavor'

# %%
type('Flavor')

# %%
Flavor

# %%
'I wouldn't ever ignore my homework'

# %%
"I wouldn't ever ignore my homework"

# %%
'"'

# %% [markdown]
# ---
#
# ### `+` with strings: **string concatenation**

# %%
"I" + "wouldn't ever ignore my homework"

# %%
"I" + " wouldn't ever ignore my homework"

# %%
"Ben" + " 10"

# %%
"Ben" + 10

# %% [markdown]
# ## How do we do it in f strings?

# %% [markdown]
# ---
# ### `len` function: returns number of characters in a string

# %%
len("hello world")

# %%
s = "Ben" + "10"

# %%
len(s)

# %%
# bonus...not tested
'ha' * 100

# %% [markdown]
# ---
#
# ## Typecasting

# %% [markdown]
# ### Strings $\rightarrow$ Numbers

# %%
int("12")

# %%
float("1.2")

# %%
int(float('3.0'))

# %%
float(int('3'))

# %% [markdown]
# ---
#
# ### Any value can be converted to a string

# %%
str(5)

# %%
str(10)

# %%
'Ben ' + str(10)

# %% [markdown]
# ---
#
# ### Conversion between number types

# %%
float(1)

# %%
2 + float(8)

# %%
2 + 8.0

# %% [markdown]
# ---
#
# ### "Conversions"

# %% [markdown]
# This will fail:

# %%
float("one point two")

# %% [markdown]
# This will "work", but you will lose the decimal place:

# %%
int(1.2)

# %%
int(1.23)

int(1.6)

# %%
round(1.6)

# %% [markdown]
# ---
#
# ### "Quick" check

# %%
lucky = 15 + 0.01
lucky = str(int(lucky)) + "3"
int(lucky) - 1

# %% [markdown]
# ---
#
# ## Arrays

# %% [markdown]
# ### Arrays are sequences of values

# %%
my_array = make_array(2, 4, 6, 8)

# %%
my_array

# %%
type(my_array)

# %%
my_array.item(1)

# %%
my_array.item(0)

# %%
my_array.item(4)

# %% [markdown]
# ---
#
# ## 1. All values in an array should have the same type.

# %% [markdown]
# ---
#
# ## 2. Arithmetic is applied to each element individually

# %%
highs = make_array(13.6, 14.387, 14.585, 15.164)

# %%
(9/5) * highs + 32

# %% [markdown]
# ---

# %%
my_array

# %%
my_array ** 2

# %%
your_array = make_array(4,5,6,7)

# %%
my_array + your_array

# %%
my_array + make_array(8,9,10,11)

# %%
my_array * make_array(8,9,10,11)

# %% [markdown]
# ---
#
# # Functions on Arrays

# %%
my_array = make_array(1, 2, 3, 4)

# %%
sum(my_array)

# %%
len(my_array)

# %%
# contrast with...
len("hello")

# %% [markdown]
# Task: How to compute mean (average) of `my_array`? Use `sum` and `len`.

# %%
# your answer here

# %% [markdown]
# ---
#
# ## NumPy Functions
#
# NumPy is a Python package for scientific computing.

# %%
import numpy as np

# %%
np.average(my_array)

# %%
np.average(make_array(30, -40, -4.5, 0, 35))

# %% [markdown]
# ---
#
# ## Documentation Practice

# %% [markdown]
# Elementwise functions

# %%
numbers_arr = make_array(5, 4, 9, 12, 100)
numbers_arr

# %%
np.sqrt(numbers_arr)

# %%
np.log(numbers_arr)   # natural log

# %%
np.log10(numbers_arr) # log base 10

# %%
np.sin(numbers_arr)

# %%
np.sqrt(144)

# %% [markdown]
# Common functions

# %%
pop_2020 = make_array(5.025, .732, 7.178, 3.012, 39.500)
pop_2020

# %%
np.mean(pop_2020)

# %%
np.average(pop_2020)

# %%
np.sum(pop_2020)

# %%
np.prod(pop_2020)

# %%
np.count_nonzero(make_array(1, 2, 3, 0, 4, 0, -5))

# %%
pop_by_year = make_array(23, 45, 93, 101, 118)
pop_by_year

# %%
np.diff(pop_by_year)

# %%
np.cumsum(pop_by_year)

# %%
pop_2020 = make_array(5.025, .732, 7.178, 3.012, 39.500)
np.sort(pop_2020)

# %%
pop_2020

# %%
pop_2021 - pop_2020

# %%
100 * (pop_2021 - pop_2020) / pop_2020

# %% [markdown]
# <br/><br/>
#
# ## More Practice, 1

# %%
empty_arr = make_array()
int_arr = make_array(3, -4, 0, 5, 2)
str_arr = make_array("cm", "m", "in", "ft", "yd")

# %%
print(empty_arr)
print(int_arr)
print(str_arr)

# %% [markdown]
# `len()`

# %%
len(str_arr)

# %%
len(empty_arr)

# %% [markdown]
# `min()`, `max()`

# %%
min(int_arr)

# %%
max(str_arr)

# %% [markdown]
# `sum()`

# %%
sum(int_arr)

# %%
sum(str_arr)

# %% [markdown]
# How would you compute the average of an array arr?

# %% [markdown]
# ## More practice, 2

# %% [markdown]
# What is the value of `five` after running this code?

# %%
threes = make_array(3, 6, 9, 12, 15)
five = threes.item(-1) + threes.item(1)
five
